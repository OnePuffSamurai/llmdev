# %%
import urllib.request
import datetime

# URLの内容を保存する関数
def save_url_content(url):
    response = urllib.request.urlopen(url)
    html = response.read().decode("utf-8")[:500]

    now = datetime.datetime.now()
    formatted = now.strftime("%Y%m%d_%H%M%S")

    with open(f"{formatted}.txt", "w") as file:
        file.write(html)
    
    return f"{formatted}.txt"

url = input("URLを入力してください: ")
file_name = save_url_content(url)
print(f"Content saved in: {file_name}")
# Out:
# Content saved in: 20260415_181229.txt
