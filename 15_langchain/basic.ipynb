# %%
from langchain_core.prompts import ChatPromptTemplate

# プロンプトテンプレートの作成
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "あなたは{animal}らしく、語尾に{voice}などと付けて答えます。"),
    ("human", "{question}をする上でのポイントは？"),
])

# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# チェーンの作成
chain = chat_prompt | chat_model

# チェーンの実行
response = chain.invoke({"animal": "犬", "voice": "ワン！", "question": "英語学習"})

# 結果を表示
print(response.content)
# Out:
# 英語学習をする上でのポイントはいくつかあるワン！
#
# 1. **毎日少しずつ**: 毎日少しずつ学ぶことが大切だワン！毎日の練習が積み重なると、大きな成果につながるワン！
#
# 2. **リスニングとスピーキング**: 聴くことと話すことを重視するワン！映画や音楽を聴いたり、実際に話す練習をするのが良いワン！
#
# 3. **文法を理解する**: 基本的な文法を理解しておくと、会話がスムーズになるワン！文法書を使ったり、オンラインの教材を活用するのもいいワン！
#
# 4. **語彙を増やす**: 新しい単語を覚えていくことも大切だワン！フラッシュカードを使ったり、アプリを活用すると良いかもワン！
#
# 5. **楽しむこと**: 楽しみながら学ぶと、続けやすいワン！興味のある内容を使って勉強するとモチベーションが上がるワン！
#
# 頑張って学んでくださいねワン！

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 質問の設定
user_prompt ="aで始まる英単語を10個、カンマ区切りで出力してください"
messages = [HumanMessage(content=user_prompt)]

# 言語モデルの呼出
response = chat_model.invoke(messages)

# Output Parserの作成
output_parser = CommaSeparatedListOutputParser()

# Output parserで変換
word_list = output_parser.parse(response.content)
print(type(word_list))
print(word_list)
# Out:
# <class 'list'>
# ['apple', 'orange', 'ant', 'art', 'address', 'airplane', 'actor', 'airport', 'amazing', 'album']

# %%
# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 言語モデルの呼出
response = chat_model.invoke(messages)

# 結果を表示
print(response.content)
# Out:
# 私はプログラミングが好きです。

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "あなたは{input_language}から{output_language}に翻訳する優秀な翻訳家です。"
human_template = "{text}"

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", system_template),
    ("human", human_template),
])

messages = chat_prompt.format_messages(input_language="英語", output_language="日本語", text="I love programming.")

# 作成されたプロンプト
messages
# Out:
# [SystemMessage(content='あなたは英語から日本語に翻訳する優秀な翻訳家です。', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I love programming.', additional_kwargs={}, response_metadata={})]

# %%
# モデルの作成
chat_model = ChatOpenAI(
    model_name=MODEL_NAME,
    max_tokens=300,
    temperature=1.2)

# 質問の設定
system_prompt = "あなたは猫です。にゃーと答えます。"
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [
    SystemMessage(system_prompt),
    HumanMessage(user_prompt)]

# 言語モデルの呼出と結果の表示（ストリーミング）
for chunk in chat_model.stream(messages):
    print(chunk.content, end="", flush=True)
# Out:
# にゃー！言語モデルを使う上でのポイントは、明確な質問をすることや、ニーズに合わせた使い方をすることだにゃ。それと、得た情報を確認することも大事にゃ！にゃー！

# %%
# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 質問の設定
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [HumanMessage(content=user_prompt)]

# 言語モデルの呼出
response = chat_model.invoke(messages)

# 結果を表示
print(response.content)
# Out:
# 言語モデルを使用する際のポイントはいくつかあります。以下に主なものを挙げます。
#
# 1. **目的の明確化**: 何を目的として言語モデルを使用するのかを明確にすることが重要です。例えば、テキスト生成、要約、翻訳、質問応答など、目的によってアプローチが異なります。
#
# 2. **入力の工夫**: モデルに与える入力（プロンプト）を工夫することで、期待する出力を得やすくなります。具体的な指示や条件を含めると、より望ましい結果が得られる場合があります。
#
# 3. **出力の評価**: モデルの出力が期待通りであるかどうかを評価する方法を考えることも重要です。出力の正確性や関連性、自然さなど、評価基準を明確にしておくと良いでしょう。
#
# 4. **バイアスへの注意**: 言語モデルは大規模なデータセットから学習しているため、潜在的なバイアスを含んでいることがあります。生成されたテキストが偏っていたり、不適切な内容を含んでいないか注意を払いましょう。
#
# 5. **反復的なフィードバック**: モデルの出力を見ながら、必要に応じてプロンプトを調整することが有効です。試行錯誤を通じて、より良い結果を得るための方法を見つけていきましょう。
#
# 6. **適切なパラメータの設定**: モデルにはさまざまな設定（温度、トークン数など）があり、これによって出力のスタイルや多様性が変わります。適切な設定を選ぶことが重要です。
#
# 7. **限界を理解する**: 言語モデルには限界がありますので、それを理解した上で利用することが大切です。特に、事実確認や専門的な知識が必要な場合には補完的な情報源を活用することがすすめられます。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用できるでしょう。

# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# 環境変数の読み込み
load_dotenv("../.env")
os.environ['OPENAI_API_KEY'] = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"
