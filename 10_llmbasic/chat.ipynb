# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下に主なものを挙げます。
#
# 1. **目的の明確化**: 何のために言語モデルを使うのか、具体的な目的を明確にすることが重要です。例えば、文章生成、翻訳、要約、質問応答など、用途によってモデルの選定やアプローチが変わります。
#
# 2. **入力の工夫**: モデルに与える入力（プロンプトやコンテキスト）の質が出力に大きく影響します。適切な文脈を提供することで、より高品質な結果を得ることができます。
#
# 3. **設定の調整**: 温度や最大トークン数など、生成過程の設定を調整することで、出力の多様性や長さをコントロールできます。実験を重ねて最適な設定を見つけることが重要です。
#
# 4. **フィードバックの活用**: モデルの出力に対してフィードバックを行い、それを基に追加のデータを収集したり、再学習を行うことで、モデルのパフォーマンスを向上させることができます。
#
# 5. **倫理的考慮**: 言語モデルの使用には倫理的な側面も関わります。バイアスや誤情報の生成を避けるために、出力を慎重に評価し、必要に応じて対策を講じることが求められます。
#
# 6. **継続的な学習**: 言語モデルは技術の進展とともに進化しています。最新の研究や技術に目を向け、必要に応じてモデルをアップデートすることが重要です。
#
# 7. **多様なデータの利用**: モデルを効果的に活用するためには、トレーニングデータの多様性や質が重要です。異なるタイプのデータを組み合わせて、モデルの理解力を高めることができます。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用できます。

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは、Aさん！最近どうですか？
# --------------------
# B:こんにちは、Aさん！最近どうですか？
# --------------------
# B:こんにちは！Aさん、元気ですか？

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# 日本は独自の文化、歴史、美しい自然が魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 伝統と現代の融合
# - **伝統的な祭り**: 日本各地で行われる祭り（例：祇園祭、ねぶた祭り）は、色鮮やかな衣装やパレードなど、地域の文化を彩ります。
# -
# --------------------
# 日本は、その豊かな文化、歴史、美しい自然、そして先進的な技術で知られています。以下に、日本の魅力をいくつか紹介します。
#
# ### 1. 歴史と文化
# - **伝統的な祭り**: 日本各地で行われる地域のお祭りには、それぞれ独自の風習やパフォーマンスがあります。たとえば、京都の祇園祭や、青森
# --------------------
# もちろんです！日本には多くの魅力があります。以下にいくつかのポイントを紹介します。
#
# 1. **文化と伝統**: 日本は豊かな歴史と伝統文化を持っています。茶道、花道、武道、和服など、古くから受け継がれてきた芸術や習慣が今でも大切にされています。
#
# 2. **美しい自然**: 山々、海、川、

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な文化、歴史、美しい自然に恵まれた国で、多くの魅力があります。以下にいくつかのポイントを紹介します。
#
# ### 1. 食文化
# - **寿司、刺身、ラーメン、天ぷら**など、多彩な料理があります。地域ごとに特色ある食材や料理 Method もあり、食べ歩く楽しみもあります。
#
# ### 2
# --------------------
# もちろんです！日本には多くの魅力があり、文化や自然、美食、歴史的な場所など様々な面で訪れる人々を魅了しています。以下にいくつかのポイントを紹介します。
#
# ### 1. **文化と伝統**
# 日本の文化は非常に豊かで、伝統芸能や祭り、新年や七夕といった行事が充実しています。茶道や花道、武
# --------------------
# 日本には多くの魅力があります。以下にいくつかのポイントを挙げてみましょう。
#
# ### 1. 文化の多様性
# 日本は、伝統文化と現代文化が共存しています。茶道、着物、歌舞伎、能楽などの伝統芸能はもちろん、多くの若者文化やポップカルチャーも豊かです。アニメやマンガは、国内外で

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略を考える際には、以下のステップを検討することが重要です。
#
# ### 1. 市場調査とターゲットの特定
# - **市場分析**: 製品が投入される市場のトレンド、競合、消費者ニーズを調査します。
# - **ターゲットペルソナの作成**: 最も興味を持つであろう顧客像を詳細に描き、マーケティング施策をターゲットに合わせます。
#
# ### 2. USP（ユニークセリングプロポジション）の明確化
# - **製品の特長**: 新製品の競争優位性や独自の特長、利点を明示化し、それをメッセージとして伝えます。
# - **ストーリーテリング**: 製品の背景や開発のストーリーを伝え、感情に訴えるコンテンツを作成します。
#
# ### 3. マーケティングチャネルの選定
# - **デジタルマーケティング**: ソーシャルメディア、ウェブ広告、SEO、コンテンツマーケティングなどを活用し、オンラインでの認知度を高めます。
# - **オフラインマーケティング**: もし適用可能なら、イベント、試飲・試用キャンペーン、印刷物を用いたプロモーションも検討します。
#
# ### 4. プロモーションプランの策定
# - **プレローンチキャンペーン**: 発売前にティーザーキャンペーンを実施し、期待感を醸成します（SNSでのカウントダウンやサンプル提供など）。
# - **インフルエンサーコラボレーション**: 業界のインフルエンサーやブロガーと提携し、製品を幅広いオーディエンスに届けます。
#
# ### 5. 発売イベントの企画
# - **ローンチイベント**: オンライン・オフライン問わず、製品発表を行うイベントを企画し、メディアや有名人を呼ぶことで注目を集めます。
#
# ### 6. フィードバックの収集と改善
# - **顧客の声を聞く**: 購入後のアンケートやSNSでの意見を集め、製品やサービスのフィードバックを得ます。
# - **改良プラン**: 得たフィードバックをもとに、製品改善や次回のプロモーション調整を行います。
#
# ### 7. 効果測定と分析
# - **KPIの設定**: マーケティング施策の効果を測定するための重要業績評価指標（KPI）を設定し、成果を定量的に評価します。
# - **データ分析**: どの施策が効果的だったかを分析し、次回の戦略に活かします。
#
# これらの戦略を組み合わせることで、新製品の発売を成功させるための基盤を構築できます。適切なリソース配分やチームビルディングも重要ですので、全体的な計画を通じて調整を行ってください。

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを効果的に使用するためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。
#
# 1. **明確な目的設定**: 何を達成したいのかを明確にすることが大切です。問い合わせや要求が具体的であればあるほど、言語モデルはより適切な応答を返しやすくなります。
#
# 2. **具体的な指示**: 特定のフォーマットやスタイル、情報の詳細度を指定することで、モデルが期待通りの応答を生成しやすくなります。
#
# 3. **コンテキストの提供**: モデルへの入力として、必要な背景情報や文脈を提供することで、より関連性の高い応答を得ることができます。
#
# 4. **フィードバックの活用**: 得られた応答に対してフィードバックを行うことで、再度の質問や指示において改善が期待できる場合があります。
#
# 5. **結果の検証**: モデルが生成した情報は誤りが含まれている可能性があるため、重要な決断を下す前に必ず情報を検証することが重要です。
#
# 6. **バイアスの理解**: モデルは訓練データに基づいているため、そこに含まれるバイアスが反映されることがあります。出力には注意を払いながら利用しましょう。
#
# 7. **創造的な利用**: 言語モデルは創造力を刺激するツールでもあります。ブレインストーミングやアイデアの生成、コンテンツの初稿作成など、さまざまな目的で利用できます。
#
# これらのポイントを考慮することで、言語モデルをより効果的に使用することができます。

# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_680cca64cb1b47afa25b03e2754ca74c',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に使用するためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。\n\n1. **明確な目的設定**: 何を達成したいのかを明確にすることが大切です。問い合わせや要求が具体的であればあるほど、言語モデルはより適切な応答を返しやすくなります。\n\n2. **具体的な指示**: 特定のフォーマットやスタイル、情報の詳細度を指定することで、モデルが期待通りの応答を生成しやすくなります。\n\n3. **コンテキストの提供**: モデルへの入力として、必要な背景情報や文脈を提供することで、より関連性の高い応答を得ることができます。\n\n4. **フィードバックの活用**: 得られた応答に対してフィードバックを行うことで、再度の質問や指示において改善が期待できる場合があります。\n\n5. **結果の検証**: モデルが生成した情報は誤りが含まれている可能性があるため、重要な決断を下す前に必ず情報を検証することが重要です。\n\n6. **バイアスの理解**: モデルは訓練データに基づいているため、そこに含まれるバイアスが反映されることがあります。出力には注意を払いながら利用しましょう。\n\n7. **創造的な利用**: 言語モデルは創造力を刺激するツールでもあります。ブレインストーミングやアイデアの生成、コンテンツの初稿作成など、さまざまな目的で利用できます。\n\nこれらのポイントを考慮することで、言語モデルをより効果的に使用することができます。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))],
#  'created': 1776649702,
#  'id': 'chatcmpl-DWY2IOeCFy4BvG38bNPAJ7L9ViKV8',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_2f65f9541c',
#  'usage': CompletionUsage(completion_tokens=426, prompt_tokens=18, total_tokens=444, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}
