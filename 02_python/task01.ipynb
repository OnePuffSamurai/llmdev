# %%
# 各出力項目を変数として定義
name = "長谷川雅英" # 名前
age = 30 # 年齢

#結果を表示
print("はじめまして、", name, "と申します。")
print("年齢は", age, "歳です。来年は", age + 1, "歳になります。")
print("よろしくお願いします。")
# Out:
# はじめまして、 長谷川雅英 と申します。
# 年齢は 30 歳です。来年は 31 歳になります。
# よろしくお願いします。
